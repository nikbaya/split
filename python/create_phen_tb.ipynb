# %%
import hail as hl

phen_dict = {
    '50':'height',
    '20160':'smoking',
    '2443':'diabetes',
    '23107':'legimp_r'
}

phen = '23107'

desc = phen_dict[phen]

# %%
phen_tb_all = hl.import_table('gs://phenotype_31063/ukb31063.phesant_phenotypes.both_sexes.tsv.bgz',missing='')
# Out:
# 2018-10-12 12:08:53 Hail: INFO: Reading table with no type imputation
#   Loading column '"userId"' as type 'str' (type not specified)
#   Loading column '"46"' as type 'str' (type not specified)
#   Loading column '"47"' as type 'str' (type not specified)
#   Loading column '"48"' as type 'str' (type not specified)
#   Loading column '"49"' as type 'str' (type not specified)
#   Loading column '"50"' as type 'str' (type not specified)
#   Loading column '"51"' as type 'str' (type not specified)
#   Loading column '"78"' as type 'str' (type not specified)
#   Loading column '"84"' as type 'str' (type not specified)
#   Loading column '"93"' as type 'str' (type not specified)
#   Loading column '"94"' as type 'str' (type not specified)
#   Loading column '"102"' as type 'str' (type not specified)
#   Loading column '"129"' as type 'str' (type not specified)
#   Loading column '"130"' as type 'str' (type not specified)
#   Loading column '"134"' as type 'str' (type not specified)
# ...

# %%
phen_tb = phen_tb_all.select(phen_tb_all['"userId"'], phen_tb_all['"'+phen+'"'])
phen_tb = phen_tb.rename({ '"userId"': 's', '"'+phen+'"': desc})
phen_tb = phen_tb.key_by('s')
phen_tb.describe()
phen_tb.count() #expect to be 361194 for every phenotype
# Out:
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Row fields:
#     's': str
#     'legimp_r': str
# ----------------------------------------
# Key: ['s']
# ----------------------------------------
# 2018-10-12 12:10:06 Hail: INFO: Coerced sorted dataset
# +-----------+-----------------------+
# | s         | legimp_r              |
# +-----------+-----------------------+
# | str       | str                   |
# +-----------+-----------------------+
# | "1000019" | "-0.347073477138494"  |
# | "1000022" | "-0.567830236494978"  |
# | "1000035" | "-0.183825733724255"  |
# | "1000046" | "-0.0105263984059161" |
# | "1000054" | "0.441260761448307"   |
# | "1000063" | "-2.16006066788146"   |
# | "1000081" | "-1.07481339679004"   |
# | "1000090" | "-0.137712701860207"  |
# | "1000105" | "1.74896117418729"    |
# | "1000129" | "-0.129636693286891"  |
# +-----------+-----------------------+
# showing top 10 rows

# %%
# phen_tb = phen_tb.filter(phen_tb[desc] == '',keep=False)
phen_tb.count()
phen_tb.export('gs://nbaya/split/phen_tables/ukb31063.hm3_variants.gwas_samples_'+phen+'_'+desc+'.tsv')
# Out:
# 2018-10-02 15:59:20 Hail: INFO: Coerced sorted dataset
# 2018-10-02 15:59:46 Hail: INFO: while writing:
#     gs://nbaya/split/phen_tables/ukb31063.hm3_variants.gwas_samples_20160_smoking_test.tsv
#   merge time: 1.079s

# %%
# phen_tb = phen_tb.annotate(phen = hl.float64(phen_tb[desc]))
# phen_tb.drop(desc).rename({'phen':desc}).show()
# Out:
# 2018-10-02 14:41:44 Hail: INFO: Coerced sorted dataset
# +-----------+-----------+
# | s         |    height |
# +-----------+-----------+
# | str       |   float64 |
# +-----------+-----------+
# | "1000019" | -4.77e-01 |
# | "1000022" |  1.26e+00 |
# | "1000035" |  1.04e+00 |
# | "1000046" | -2.15e-01 |
# | "1000054" |  1.07e+00 |
# | "1000063" |  1.27e+00 |
# | "1000081" |  8.73e-01 |
# | "1000090" |  1.27e-01 |
# | "1000105" | -2.30e+00 |
# | "1000129" |  1.61e+00 |
# +-----------+-----------+
# showing top 10 rows

# %%
# phen_tb_old = hl.import_table('gs://nbaya/split/phen_tables/ukb31063.hm3_variants.gwas_samples_'+phen+'_'+desc+'.tsv', impute=True, types={'s': hl.tstr})
# phen_tb_old.show()
# Out:
# Initializing Spark and Hail with default parameters...
# Running on Apache Spark version 2.2.1
# SparkUI available at http://10.128.0.56:4041
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version devel-654043004581
# NOTE: This is a beta version. Interfaces may change
#   during the beta period. We recommend pulling
#   the latest changes weekly.
# LOGGING: writing to /home/hail/hail-20181002-1535-devel-654043004581.log
# 2018-10-02 15:35:26 Hail: INFO: Reading table to impute column types
# 2018-10-02 15:35:31 Hail: INFO: Finished type imputation
#   Loading column 's' as type 'str' (user-specified)
#   Loading column 'sa.covariates.isFemale' as type 'bool' (imputed)
#   Loading column 'sa.covariates.age' as type 'int32' (imputed)
#   Loading column 'sa.covariates.age_squared' as type 'float64' (imputed)
#   Loading column 'sa.covariates.age_isFemale' as type 'int32' (imputed)
# ...
